# %%
import torch.nn as nn
import torch
import torchvision.models as models
model_conv = models.resnet50(pretrained=True)
for param in model_conv.parameters():
    param.requires_grad = False
num_ftrs = model_conv.fc.in_features
print(model_conv.fc.in_features)
# Out:
# 2048

# %%
model_conv.fc = nn.Linear(num_ftrs,300)
print(model_conv.fc)

embed = nn.LSTM(300,256)

model = nn.Sequential(
    model_conv,
    embed
)
# Out:
# Linear(in_features=2048, out_features=300, bias=True)

# %%
from experiment import Experiment
import sys

exp_name = 'default'


print("Running Experiment: ", exp_name)
exp = Experiment(exp_name)
print(exp)
# Out:
# Running Experiment:  default
# loading annotations into memory...
# Done (t=0.83s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.31s)
# creating index...
# index created!
# Using the saved vocab.
# loading annotations into memory...
# Done (t=0.63s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.63s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.32s)
# creating index...
# index created!
# <experiment.Experiment object at 0x7efb6d20e650>

# %%
exp.run()
result = None
for i, (images,captions,idk) in enumerate(exp.train_loader):
    if i == 0:
        images = images.to("cuda")
        captions = captions.to("cuda")
        print(images.shape)
        result = exp.model.generate(images,exp.vocab,20)
        break
# Out:
# 0 number epoch
# 2.682289778981422
# <start> a partial view of a man showing his leg and arm only holding on to a yellow frisbee . <end>
# <start> a man with of a man in a a . a . . a a . table . . <end>
# <start> a car driving down a road near a field where a zebra and two giraffes are standing by a rock . <end>
# <start> a man is of a street with a table . . table . a . . . in a table . <end>
# <start> an old lady and a young man sitting in front of a table on which a cake is <unk> wine glasses are also there . <end>
# <start> a old man is a white man in on a of a building . a . . . . . . . . . . <end>
# <start> a man is typing on his keyboard behind a monitor in the back of the living room . <end>
# <start> a man is sitting a a in with a table . the background . a water . . <end>
# <start> on top of a table and on a tray are three donuts that are yellow , green glazed and plain glazed <end>
# <start> a a of a man with a a table . . . . . . . and and . a . .
# <start> a cat is sitting alone in the middle of a large patio area with a historical building in the background . <end>
# <start> a man is sitting on on a snow of a building . . . a building . . the background . <end>
# <start> a person sits at a table with a gun , multiple cellular phones , a flask of alcohol and a cup . <end>
# <start> a man is on a table with a table . and and and . and and and a . a white . <end>
# <start> the home plate area of a baseball field , with a the batter in a swinging motion and the umpire and catcher looking towards the left field . <end>
# <start> a man is is a a man player . and a large and . the table . . a . . a . . . . . . <end>
# <start> two bowls of food on a table , one with fruit and the other with pasta and meat in it <end>
# <start> a people of a and a table with and and a and a . . a . a . the .
# <start> a woman from side , from knees up , bending at waist , wearing visor , and holding a tennis racket in front with both hands , on dirt . <end>
# <start> a man is a of a a a and and and a . and and and and a . table . . the of a . . and a . <end>
# <start> a surfer wearing a green shirt holds his surf board and looks out at the boats in the ocean . <end>
# <start> a man of a white and and a on . . a . . a water . the background . <end>
# <start> a car is sitting at a street corner in a town while people wait to cross the street . <end>
# <start> a man is sitting on a table with . a table . . . . a . . . <end>
# <start> a mascot sits on one side of a blue table while two men sit on the other side looking the other direction . <end>
# <start> a man with on a of of a table . . . . . . a street . . . . . . <end>
# <start> a giraffe looking to its left with some hay hanging from its mouth . <end>
# <start> a man is in a in a a <end> . . a . . <end>
# <start> a woman in a red dress with a black handbag standing on the street while holding a cell phone to her ear . <end>
# <start> a man is a white with with a white and . . a street . . a table . . a . . <end>
# <start> a red stop sign with the word `` do n't `` above it and the word `` believing `` below it . <end>
# <start> a man and sign with a and of on a . . . . a . . . . . . . <end>
# <start> three young children are engaged in an activity as an woman assists one of the children near an elderly woman at a table . <end>
# <start> a people are in in a the umbrella . . . . . . a water . a . . . a table . <end>
# <start> nice size kitchen with a marble top island , big in the wall fridge , and sink with long counter <end>
# <start> a people is with a white and of . a and a background . . . a . a . .
# <start> the men are talking on a sidewalk under a streetlight , in view of a child 's bike with a broken training wheel . <end>
# <start> a man is sitting on a table . a table . . a . a building . . . a table . . . <end>
# <start> a man in blue shorts holds a rope as he stands on a boogie board on the water . <end>
# <start> a man is a a with a white . a . . a table . . a street . <end>
# <start> a woman sitting at a table and looking at a birthday cake with some lit candles on it <end>
# <start> a man is on a table with a . a table . . a . . . a .
# <start> dinner is served in platters , the left consists of meat , and vegetable ravioli and the one on the right contains fresh fruits . <end>
# <start> a and sitting on a a and water . . a . and a . . a water . a background . . . . <end>
# <start> a man standing next to a street with an elephant next to him that has a painted face and trunk , <end>
# <start> a man is in to a tennis with a umbrella . to a . . a table . . a . and
# <start> a red bench sits unoccupied as a person stands on a beach in the sunset . <end>
# <start> a man and with on a a table <end> . a table . the background . <end>
# <start> a close up view of an orange and an apple on a wooden table . <end>
# <start> a man of of of a old and white umbrella . a table . . <end>
# <start> a view of a <unk> room with a yellow couch and a red painting behind it . <end>
# <start> a man of a man with with a table and . a white . . . . <end>
# <start> a woman sitting at a table with a knife in fork in her hand and a large salad in the middle of the table . <end>
# <start> a man is on a table with a table . a . the . . a white . . the background of a water . <end>
# <start> a street with a fire hydrant that has been painted white and weeds and grass growing around it . <end>
# <start> a man with a white hydrant on is a and . . a . a . . . . <end>
# <start> a young girl standing outside of a white fence and reaching out to a brown and white horse that is leaning over the fence to her . <end>
# <start> a man man is in a a street and . a . . a table . white . . is on on a water . a . <end>
# <start> a young lady with a cowboy hat sits at a table that has a <unk> and several cellphones on it , among other things . <end>
# <start> a man man is a white and on on a table . . a table . a . . a . . . . . <end>
# <start> a large neon sign that says `` czech stop '' and a yellow symbol on top attached to a tall pole . <end>
# <start> a man white with with is a on . . . a table . . a of . a table . . <end>
# <start> a large group of cows eat hay through a barrier , while people look on . <end>
# <start> a man white of people in in a a table . . . . . a <end>
# <start> three men in wet suits surfing on the waves and a man in a grey wet suit and yellow surfboard entering the water . <end>
# <start> a people are a and in in a side . a table . a field . . . a . . . . . <end>
# <start> a woman goes to throw a frisbee on an indoor court while a male play stands in front of her . <end>
# <start> a man is a a a table in a . . . . table . . . the of a . <end>
# <start> an untidy room with a cat sleeping in a chair by a window and a messy computer desk area . <end>
# <start> a old with with a large and on a table . . table . a table . . . . <end>
# <start> an airplane with two wings has a blue and grey plastic extender is away from the door of the aircraft . <end>
# <start> a old with a and on a table and white <end> . . . . a . . a water . <end>
# <start> a stuffed animal teddy bear that is sitting on a mouse pad , in front of a computer keyboard . <end>
# <start> a man of with a on is on on a table . . . the of a building . . <end>
# <start> a mother carries a dish to the sink , and a young man carries a beer bottle toward a counter , as a young girl looks on . <end>
# <start> a man and with white with a street . a a white . . . table . . . . . and and table . . . a <end>
# <start> a book shelf loaded with books and binders and a toy steering wheel at the top of the shelf . <end>
# <start> a man is with a a and a . a white . . . a water of a water . <end>
# <start> a man in a black and white baseball uniform stands with a bat as a ball hovers near him and a catcher holds out his mitt behind him . <end>
# <start> a man is a white and white white with with on a table . . table . . a . a table . . . . . a . <end>
# <start> a man walks by a surfboard on the beach as a child plays in the water . <end>
# <start> a man is a a tennis with a street . a table . . the background . <end>
# <start> bunk beds in a bedroom with a bag on top of the bottom bunk . <end>
# <start> a of a a white with a white . a of a water . . <end>
# <start> a white frosted cake with candy decorations and a plate of muffins are placed on a table . <end>
# <start> a man and with with a and and a white . a . . . a table . <end>
# <start> a first baseman stands with his hand in his glove as the crowd looks on from the stands in the background . <end>
# <start> a man of with on a and on the . . . . . . a . . . the background . <end>
# <start> this is a rear view of a roadway in which cars are in the right lane and <unk> occupy the left lane while no vehicle is in the left turn lane . <end>
# <start> a is a man in of a man on a . . . the background . . a . . . . . . . . . the background . . . <end>
# <start> a bathroom with a commode and a wall on the other side of which is a double vanity with an upscale counter and back splash . <end>
# <start> a man with a white and white white . a street . . a . . . . . a umbrella . . a . . <end>
# <start> a man and a woman in front of a small oven with the woman setting the dials and the man crouching down . <end>
# <start> a man is a white in a of a street . . a water . . . . a . . . a <end>
# <start> a building with one side open , with black and white cows and with brown and white cows lined up feeding on hay and people standing lined up looking at them . <end>
# <start> a man with a and of on and a and a . . a a . a . . . . . a . a . . . . . the . <end>
# <start> a doubledecker bus on a city street has passed knot of pedestrians and is passing buildings and cars and headed towards a crosswalk and streetlight . <end>
# <start> a man of with a table with . a . . a . a . . . a . a . . table . a . <end>
# <start> a cardboard sign reading `` rowan '' lays on the ground with broccoli wrapped in newspaper on top . <end>
# <start> a man of with a on on on . a water . a . . the . a of <end>
# <start> the desk and the microwave have been left out on the side of the road . <end>
# <start> a man is a street is a on a . the side . a water . <end>
# <start> a group of boys are at a carnival and one boy in yellow is throwing a ball at a batter . <end>
# <start> a man of people are standing a table . white . . the . . . . . a table . <end>
# <start> a tall case of flowers on an elaborate dining area sit alongside two wine glasses and a dish . <end>
# <start> a man of with a and a umbrella . . . . . . . . a large . <end>
# <start> close up of a box tied with a bow sitting on the top of a toilet tank in a bathroom <end>
# <start> a up of a man of on a table . on a street of a table . . a table .
# <start> there are two street signs , a white truck is turing on to the lane an a man is walking on the sidewalk . <end>
# <start> a is are men on in a table and and on . a . . . . table . . . a water . <end>
# <start> the inside of a building with various pieces of luggage and bags all placed in lines next to one another . <end>
# <start> a man of a man with a and and a . a . . . the . to a . . <end>
# <start> a person dressed in winter clothing and snowboarding on a city street with cars parked on the sides and covered in snow . <end>
# <start> a man is a a a with a . a table . . a . . the . . a . the . <end>
# <start> a man is swinging a bat and running as another man holds out his hand behind him . <end>
# <start> a man is sitting a tennis in a on a . . a . . . a . <end>
# <start> a batter swings at a ball while the catcher closes his glove in an attempt to catch the ball . <end>
# <start> a man is of a table with a street . . . . the . . . . . . <end>
# <start> four men standing next to each other while another man holds a leash on a dog sniffing at one of the men 's shoes . <end>
# <start> a people are in to a other in a . . a table . a table . . a . a . . . . <end>
# <start> a cake for a some side of celebration with the top covered with fruit and 3 very long candles . <end>
# <start> a man with a white with of a . a water of . a . a . . . . <end>
# <start> a white mouse laying on top of a cat who is laying on top of a dog . <end>
# <start> a man and is on a of a table . . . . a of a table . <end>
# <start> a man on a skateboard skating near an orange trash can as people stand by with their skate boards . <end>
# <start> a man is a table in a a umbrella . . . . . . a a . . . <end>
# <start> a pair of scissors that are set on a table next to a credit card that has been cut into several pieces like a puzzle . <end>
# <start> a man of a in is on on a table . to a table . . is a . . . . . . . . <end>
# <start> a street light post has two street signs on it , including the sign for `` pirate 's alley '' . <end>
# <start> a man with with a a and and . a . . . . . a . . . . . <end>
# <start> view at open car door of back seat area filled with various skis and ski poles . back of front seat and head rest , and illuminated ceiling light . <end>
# <start> a of a in with on a and a . . a . . a . . <end> <end> a of a a . . . a . . . <end>
# <start> a man walks down the road with a bag in his hand , but several lamb are following him . <end>
# <start> a man is a a side with a table . the . . . . . . . . . <end>
# <start> a street sign pointing in one direction with the word `` spring st '' as the other sign points in the other direction of `` broadway '' . <end>
# <start> a man with with a a with . a water . . . . . . water . . . the background . . a . . . <end>
# <start> man in between two women with medals on his chest and in a case he is showing . <end>
# <start> a is a a a in a and a . . a the table . . . . <end>
# <start> a young child dressed nicely in a blue sports jacket and tie leaning on a rail . <end>
# <start> a man man is a with a field <end> . . a . . a table . <end>
# <start> a glass table with a spinach pizza , a bottle of wine , and two filled glasses . <end>
# <start> a man of with a white of on and and and a . and a and . . <end>
# <start> picture of a steeple and clocks on a building with a snow covered roof with a neon sign in the distance . <end>
# <start> a of a man and a on a table . a table . . . a table . . the background . <end>
# <start> a table and chairs sit in a garden next to a tree surrounded by small plants and a shed with a red door . <end>
# <start> a man with a on on a field . to a table . . a . . a table . a large . . <end>
# <start> a long line of motorcyclists driving in a straight line while a group of people watch from a city sidewalk . <end>
# <start> a man with with a on on the table . . . . of a . . a table . . <end>
# <start> a man with a goatee and black and white shirt and a boy and an orange <end>
# <start> a man is a white and white and white and . a white . a umbrella .
# <start> people are laying in a grassy area alongside a road with a homemade sign taped on a meter . <end>
# <start> a are standing on a field field . . table . a table . . . a table . <end>
# <start> a young girl bounces a tennis ball in the air on her tennis racket . <end>
# <start> a man man is a man player with a water . a . . . <end>
# <start> a car waits to drive down a country road while a man walks in front of a herd of sheep , blocking the way . <end>
# <start> a man is is a a a street . . . street . . the of a building of a . . . . . <end>
# <start> a man at a baseball game is holding his bat on the ground with is head on top it . <end>
# <start> a man is a tennis player with on a . . a side . a . . the of . <end>
# <start> one slice of bread with cream cheese and tomatoes and another slice of bread with some meat . <end>
# <start> a and of a and a and on a . a . . a . a . . <end>
# <start> two women wearing white tennis dresses and holding rackets are walking on each side of the tennis court net . <end>
# <start> a person with a snowboard attached to their feet , doing a head stand in the snow . <end>
# <start> a man is a white and on a a . and . table . . the background . <end>
# <start> a piece of bread is spread with butter and fish pieces as it sits next to sliced tomatoes . <end>
# <start> a man of a and sitting a a and a . . . . . to a . . <end>
# <start> the pair of soldiers cutting the cake were <unk> by a pair of hot <unk> and a <unk> in a suit . <end>
# <start> a man of a are a side with . . . table . a . . a large . the field . <end>
# <start> a person has there hand on a machine that you can push as a yellow fire hydrant sits on a plastic tarp . <end>
# <start> a man is a is on a table . . . . . . table . . . . a table . . <end>
# <start> a blue sky seems to melt into a lightly rippling body of blue water , on which rests a child and a woman that are lying head to feet , woman behind the child , on a surfboard , while a young man sits behind the two . <end>
# <start> a man of is with a of a table . . . a . . . a . . . . a table . is . . . a . . . a background . and a table . and and table . . on a water . <end>
# <start> lady smiling with slice of cheesy pizza in her hand and two bottle of beer in front of her . <end>
# <start> a is and a and a and on a . . a . . a . the of a . <end>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a668db483423> in <module>
# ----> 1 exp.run()
#       2 # result = None
#       3 # for i, (images,captions,idk) in enumerate(exp.train_loader):
#       4 #     if i == 0:
#       5 #         images = images.to("cuda")
#
# ~/PA4/experiment.py in run(self)
#     105             print(train_loss)
#     106             val_loss = self.__val()
# --> 107             self.__record_stats(train_loss, val_loss)
#     108             self.__log_epoch_stats(start_time)
#     109             #####################################################################
#
# ~/PA4/experiment.py in __record_stats(self, train_loss, val_loss)
#     179         self.__val_losses.append(val_loss)
#     180
# --> 181         self.plot_stats()
#     182
#     183         write_to_file_in_dir(self.__experiment_dir, 'training_losses.txt', self.__training_losses)
#
# ~/PA4/experiment.py in plot_stats(self)
#     209         plt.legend(loc='best')
#     210         plt.title(self.__name + " Stats Plot")
# --> 211         plt.savefig(os.path.join(self.__experiment_dir, "stat_plot.png"))
#     212         plt.show()
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     721 def savefig(*args, **kwargs):
#     722     fig = gcf()
# --> 723     res = fig.savefig(*args, **kwargs)
#     724     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     725     return res
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2103                     orientation=orientation,
#    2104                     bbox_inches_restore=_bbox_inches_restore,
# -> 2105                     **kwargs)
#    2106             finally:
#    2107                 if bbox_inches and restore_bbox:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     533         else:
#     534             renderer = self.get_renderer()
# --> 535             with cbook.open_file_cm(filename_or_obj, "wb") as fh:
#     536                 _png.write_png(renderer._renderer, fh, self.figure.dpi,
#     537                                metadata={**default_metadata, **metadata})
#
# /opt/conda/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in open_file_cm(path_or_file, mode, encoding)
#     416 def open_file_cm(path_or_file, mode="r", encoding=None):
#     417     r"""Pass through file objects and context-manage `.PathLike`\s."""
# --> 418     fh, opened = to_filehandle(path_or_file, mode, True, encoding)
#     419     if opened:
#     420         with fh:
#
# /opt/conda/lib/python3.7/site-packages/matplotlib/cbook/__init__.py in to_filehandle(fname, flag, return_opened, encoding)
#     401             fh = bz2.BZ2File(fname, flag)
#     402         else:
# --> 403             fh = open(fname, flag, encoding=encoding)
#     404         opened = True
#     405     elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './experiment_data/default_experiment/stat_plot.png'

# %%
for i in result:
    print(exp.vocab.idx2word[i[0].item()])

# %%
# import matplotlib.pyplot as plt

# #plt.imshow(my_tensor.numpy()[0], cmap='gray')
# def generate_caption(vocab,captions):
#     string = ""
#     for word in captions:
#         string = string + vocab.idx2word[word.item()] + " "
#     print(string)

        
# def view_sent(output,vocab):
#     predicted = []
#     string = ""
#     for i in output:
#         wordidx = torch.argmax(i).item()
#         string += vocab.idx2word[wordidx] + " "
#     print(string)
# loss_t = 0
# for j in range(10):        
#     for i, (images,captions,idk) in enumerate(exp.train_loader):
#         images = images.to("cuda")
#         captions = captions.to("cuda")

#         output = exp.model(images,captions)
#         #print(output.shape,captions.shape)
#         loss = exp.criterion(output.reshape(-1,len(exp.vocab)),captions.reshape(-1))
#         loss_t+=loss
#         if i % 50 == 0:
#             print(loss,i)
#             generate_caption(exp.vocab,captions[0])
#             view_sent(output[0],exp.vocab)
#         loss.backward()
#         exp.optimizer.step()
